# %% [markdown]
# <div style="display:flex; justify-content:center; align-items:center; position:relative;">
#
#   <h2 style="margin:auto; text-align:center;">
#     UNIVERSIDAD TÉCNICA DEL NORTE <br>
#     Facultad de Ingeniería en Ciencias Aplicadas - FICA
#   </h2>
#
#   <img src="https://wstemproject.eu/files/2019/06/logo-UTN-2017-768x768.png"
#        width="100px">
# </div>
#
# <h4 style="text-align:center;"> CARRERA DE CIENCIA DE DATOS E INTELIGENCIA ARTIFICIAL </h4>
#
# <h4 style="text-align:center;"> PROGRAMACIÓN II </h4>
#
# <h4 style="text-align:center;"> Trabajo Exploratory Data Analysis  </h4>
#
# <h5 style="text-align:right;"> Docente: Ing. Wilson Pérez </h5>
# <h5 style="text-align:right;"> Estudiantes: .......... </h5>
# <h5 style="text-align:right;"> Marzo - Septiembre 2026</h5>

# %% [markdown]
# ***
# #### Exploratory Data Analysis
#
# #### Tema: ...............
#
# ##### Contexto
#
# ....................

# %% [markdown]
# ##### Describir el conjunto de datos (1 punto)

# %% [markdown]
# #### Objetivo general
#
# ........................................
# #### 1. Importar librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2. Leer el dataset

# %%
path = '/Users/xxxxxx.csv'

# %% [markdown]
# #### Mostrar

# %%
df.info()

# %%
print(df.shape)
# Out:
# (255, 13)

# %% [markdown]
# #### 3. Limpieza de datos (2 puntos)
#
# Existe datos incorrectos o duplicados o nulos en el dataset? Cómo se los trata?

# %% [markdown]
# #### 4. Crear nuevas variables (2 puntos)
# Crear columnas adicionales resultados de transformar o de realizar cálculos.

# %% [markdown]
# #### 5. Estadística descriptiva (1 punto)
#
# ¿Cómo se encuentras distribuido los columnas? (media, mediana)

# %% [markdown]
# #### 6. Gráfico de resultados (2 puntos)
# Qué resultados se encuentran del conjunto de dataset?

# %% [markdown]
# a. Graficar diagramas de caja y bigote. Comentar hallazgos. (0.5 puntos)

# %% [markdown]
# b. Graficar histogramas de las dos columnas, incluir el título de cada gráfico y un tamaño de figura. Comentar hallazgos. (0.5 puntos)

# %% [markdown]
# c. En base a estos gráficos, ¿hay datos atípicos? Si los hay, ¿en dónde? ¿dónde se concentran los datos en las dos variables?. (0.5 puntos)

# %% [markdown]
# d. Realizar un diagrama de dispersión en base a las dos columnas. Incluir el título y graficar en tamaño. Comentar hallazgos. (0.5 puntos)

# %% [markdown]
# #### 7. Resultados a obtener (2 punto)
# ¿Qué conclusiones se puede obtener luego del EDA del dataset de estudio? (1 punto)

# %% [markdown]
# ¿Qué conocimiento nuevo se puede obtener con el dataset de estudio? ¿Cómo? (1 punto)
